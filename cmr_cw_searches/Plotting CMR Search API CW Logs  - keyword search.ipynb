# %%
import boto3
from datetime import datetime, timedelta
import json
import matplotlib.pyplot as plt
import requests
import time

# %%
# NOTE: You will need to set AWS access keys for the MCP environment

# %%
# %%time
client = boto3.client('logs', region_name='us-west-2')

query = """
fields @timestamp, @message
| filter @message like "cmr.search.api"
| filter @message like ":keyword"
| parse @message /:keyword "(?<keyword>.+)\*"/
| stats count(*) as number_queries by tolower(keyword)
| sort by number_queries desc
"""

print(query)
log_group = 'cmr-search-ops'
datetime_str = '05/18/22 00:00:00'
starting_datetime_object = datetime.strptime(datetime_str, '%m/%d/%y %H:%M:%S')

start_query_response = client.start_query(
    logGroupName=log_group,
    startTime=int(starting_datetime_object.timestamp()),
    endTime=int(datetime.now().timestamp()),
    queryString=query,
)

query_id = start_query_response['queryId']

logs_response = None

while logs_response == None or logs_response['status'] == 'Running':
    print('Waiting for query to complete ...')
    time.sleep(10)
    logs_response = client.get_query_results(
        queryId=query_id
    )
# Out:
# fields @timestamp, @message
# | filter @message like "cmr.search.api"
# | filter @message like ":keyword"
# | parse @message /:keyword "(?<keyword>.+)\*"/
# | stats count(*) as number_queries by tolower(keyword)
# | sort by number_queries desc
#
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# CPU times: user 1 s, sys: 94.9 ms, total: 1.1 s
# Wall time: 9min 22s

# %%
# Save the results so we don't have to re-run the query
filename = f"keyword_search-{query_id}.json"
with open(filename, "w+") as f:
    f.write(json.dumps(logs_response))
    f.close()

# %%
data = json.loads(open(filename).read())
data
# Out:
# {'results': [[{'field': 'tolower(keyword)', 'value': 'gedi'},
#    {'field': 'number_queries', 'value': '81'}],
#   [{'field': 'tolower(keyword)', 'value': 'biomass'},
#    {'field': 'number_queries', 'value': '40'}],
#   [{'field': 'tolower(keyword)', 'value': 'gedi* l2b'},
#    {'field': 'number_queries', 'value': '40'}],
#   [{'field': 'tolower(keyword)', 'value': 'afrisar'},
#    {'field': 'number_queries', 'value': '22'}],
#   [{'field': 'tolower(keyword)', 'value': 'afrisar_dlr'},
#    {'field': 'number_queries', 'value': '21'}],
#   [{'field': 'tolower(keyword)', 'value': 'gedi* l4b'},
#    {'field': 'number_queries', 'value': '18'}],
#   [{'field': 'tolower(keyword)', 'value': 'atl08'},
#    {'field': 'number_queries', 'value': '18'}],
#   [{'field': 'number_queries', 'value': '16'}],
#   [{'field': 'tolower(keyword)', 'value': 'gedi* l4a'},
#    {'field': 'number_queries', 'value': '10'}],
#   [{'field': 'tolower(keyword)', 'value': 'cci'},
#    {'field': 'number_queries', 'value': '10'}],
#   [{'field': 'tolower(keyword)', 'value': 'afrisar_uavsar_coreg_slc'},
#    {'field': 'number_queries', 'value': '9'}],
#   [{'field': 'tolower(keyword)', 'value': 'l2b'},
#    {'field': 'number_queries', 'value': '9'}],
#   [{'field': 'tolower(keyword)',
#     'value': 'afrisar* uavsar* coregistered* slcs* generated* using* nisar* tools'},
#    {'field': 'number_queries', 'value': '8'}],
#   [{'field': 'tolower(keyword)',
#     'value': 'afrisar:* aboveground* biomass* for* lope,* mabounie,* mondah,* and* rabi* sites,* gabon'},
#    {'field': 'number_queries', 'value': '7'}],
#   [{'field': 'tolower(keyword)', 'value': 'aflvis2'},
#    {'field': 'number_queries', 'value': '7'}],
#   [{'field': 'tolower(keyword)', 'value': 'atl03'},
#    {'field': 'number_queries', 'value': '6'}],
#   [{'field': 'tolower(keyword)', 'value': 'viirs'},
#    {'field': 'number_queries', 'value': '6'}],
#   [{'field': 'tolower(keyword)', 'value': 'biosar1'},
#    {'field': 'number_queries', 'value': '6'}],
#   [{'field': 'tolower(keyword)', 'value': 'dem'},
#    {'field': 'number_queries', 'value': '6'}],
#   [{'field': 'tolower(keyword)', 'value': 'l4a'},
#    {'field': 'number_queries', 'value': '6'}],
#   [{'field': 'tolower(keyword)', 'value': 'landsat'},
#    {'field': 'number_queries', 'value': '5'}],
#   [{'field': 'tolower(keyword)', 'value': 'neon'},
#    {'field': 'number_queries', 'value': '5'}],
#   [{'field': 'tolower(keyword)', 'value': 'dbh* tape'},
#    {'field': 'number_queries', 'value': '4'}],
#   [{'field': 'tolower(keyword)', 'value': 'gedi* l3'},
#    {'field': 'number_queries', 'value': '4'}],
#   [{'field': 'tolower(keyword)', 'value': 'l2a'},
#    {'field': 'number_queries', 'value': '4'}],
#   [{'field': 'tolower(keyword)', 'value': 'esa_maap'},
#    {'field': 'number_queries', 'value': '4'}],
#   [{'field': 'tolower(keyword)', 'value': 'atl'},
#    {'field': 'number_queries', 'value': '4'}],
#   [{'field': 'tolower(keyword)',
#     'value': 'forest* structure* and* biomass* database'},
#    {'field': 'number_queries', 'value': '4'}],
#   [{'field': 'tolower(keyword)', 'value': 'c1201746153-nasa_maap'},
#    {'field': 'number_queries', 'value': '4'}],
#   [{'field': 'tolower(keyword)', 'value': 'hls'},
#    {'field': 'number_queries', 'value': '3'}],
#   [{'field': 'tolower(keyword)', 'value': 'jpl'},
#    {'field': 'number_queries', 'value': '3'}],
#   [{'field': 'tolower(keyword)', 'value': 'fsdb'},
#    {'field': 'number_queries', 'value': '3'}],
#   [{'field': 'tolower(keyword)', 'value': 'modis'},
#    {'field': 'number_queries', 'value': '3'}],
#   [{'field': 'tolower(keyword)', 'value': 'esa'},
#    {'field': 'number_queries', 'value': '3'}],
#   [{'field': 'tolower(keyword)', 'value': 'uavsar'},
#    {'field': 'number_queries', 'value': '3'}],
#   [{'field': 'tolower(keyword)', 'value': 'gedi* '},
#    {'field': 'number_queries', 'value': '3'}],
#   [{'field': 'tolower(keyword)', 'value': 'esacci'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)', 'value': 'water'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)', 'value': 'rainforest* canopy'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)', 'value': 'sentinel'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)',
#     'value': 'atlas/icesat-2* l3a* land* and* vegetation* height* v002'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)', 'value': 'lvis'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)', 'value': 'uavsar* afrisar* '},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)', 'value': 'uavsar_afrisar_v1_slc'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)', 'value': 'slc'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)',
#     'value': 'arctic-boreal* vulnerability* experiment* uninhabited* aerial* vehicle* synthetic* aperture* radar* polarimetric* sar'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)', 'value': 'icesat'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)', 'value': 'sar'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)', 'value': 'afrisar_agb_maps_1681'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)', 'value': 'biosar'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)', 'value': 'uavsar_afrisar'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)', 'value': 'l4b'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)',
#     'value': 'gedi_l3_landsurface_metrics_v2_1952'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'tolower(keyword)', 'value': 'llc90'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'merr'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'plate* tectonics'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'tape'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)',
#     'value': 'afrisar:* rainforest* canopy* height* derived* from* polinsar* and* lidar* data,* gabon'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'jpl* 2020'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)',
#     'value': 'esacci_biomass_l4_agb_v3_100m_2010'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'afrisar* lvis'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)',
#     'value': 'uavsar_afrisar_v1_slc_4326_0000141205'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'agb_2020'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'gedi02_b'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'bionmass'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)',
#     'value': 'usa_neonbarr_2019_neon_d18_barr_dp1_576000_7909000_classified_point_cloud_colorized.las.json'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'neonjerc'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'biomas'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'uavsar* afrisar'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'copernicus'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'nis'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'biom'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'onera'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)',
#     'value': 'afrisar:* canopy* structure* derived* from* polinsar* and* coherence* tomosar* nisar* tools'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': '2020'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'circulation'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'ablvis'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'gedi* l4a* '},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'gedi* calval'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'dbh* tape1'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'gedi* l2a'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'trop'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'calval'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'uavsar_afrisar_v1'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'uavsar* afrisar* v1* slc'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'agb* 2020'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'population'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)',
#     'value': 'viirs/npp* raw* radiances* in* counts* 6-min* l1a* swath* nrt'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'dbh'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'srtm'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)',
#     'value': 'esacci_biomass_l4_agb_v3_100m_2017'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'tropisar'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'c1200231010-nasa_maap'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'maap'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'boreal* agb'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'indrex'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'cal/val'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'surface* elevation'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'ecco'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'ocean'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'llc'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'merra-2'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)',
#     'value': 'afrisar_lvis_biomass_vprofiles_1775'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)',
#     'value': 'afrisar:* gridded* forest* biomass* and* canopy* metrics* derived* from* lvis,* gabon,* 2016'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'brix'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'tolower(keyword)', 'value': 'edav'},
#    {'field': 'number_queries', 'value': '1'}]],
#  'statistics': {'recordsMatched': 492.0,
#   'recordsScanned': 13113250.0,
#   'bytesScanned': 3415852653.0},
#  'status': 'Complete',
#  'ResponseMetadata': {'RequestId': '91552d30-7e63-4987-8602-fd8b47cc8465',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '91552d30-7e63-4987-8602-fd8b47cc8465',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '10368',
#    'date': 'Wed, 19 Oct 2022 22:19:04 GMT'},
#   'RetryAttempts': 0}}

# %%
restructured_data = []
for result in logs_response['results']:
    entry_data = {}
    for entry in result:
        entry_data[entry['field']] = entry['value']
    restructured_data.append(entry_data)

restructured_data
# Out:
# [{'tolower(keyword)': 'gedi', 'number_queries': '81'},
#  {'tolower(keyword)': 'biomass', 'number_queries': '40'},
#  {'tolower(keyword)': 'gedi* l2b', 'number_queries': '40'},
#  {'tolower(keyword)': 'afrisar', 'number_queries': '22'},
#  {'tolower(keyword)': 'afrisar_dlr', 'number_queries': '21'},
#  {'tolower(keyword)': 'gedi* l4b', 'number_queries': '18'},
#  {'tolower(keyword)': 'atl08', 'number_queries': '18'},
#  {'number_queries': '16'},
#  {'tolower(keyword)': 'gedi* l4a', 'number_queries': '10'},
#  {'tolower(keyword)': 'cci', 'number_queries': '10'},
#  {'tolower(keyword)': 'afrisar_uavsar_coreg_slc', 'number_queries': '9'},
#  {'tolower(keyword)': 'l2b', 'number_queries': '9'},
#  {'tolower(keyword)': 'afrisar* uavsar* coregistered* slcs* generated* using* nisar* tools',
#   'number_queries': '8'},
#  {'tolower(keyword)': 'afrisar:* aboveground* biomass* for* lope,* mabounie,* mondah,* and* rabi* sites,* gabon',
#   'number_queries': '7'},
#  {'tolower(keyword)': 'aflvis2', 'number_queries': '7'},
#  {'tolower(keyword)': 'atl03', 'number_queries': '6'},
#  {'tolower(keyword)': 'viirs', 'number_queries': '6'},
#  {'tolower(keyword)': 'biosar1', 'number_queries': '6'},
#  {'tolower(keyword)': 'dem', 'number_queries': '6'},
#  {'tolower(keyword)': 'l4a', 'number_queries': '6'},
#  {'tolower(keyword)': 'landsat', 'number_queries': '5'},
#  {'tolower(keyword)': 'neon', 'number_queries': '5'},
#  {'tolower(keyword)': 'dbh* tape', 'number_queries': '4'},
#  {'tolower(keyword)': 'gedi* l3', 'number_queries': '4'},
#  {'tolower(keyword)': 'l2a', 'number_queries': '4'},
#  {'tolower(keyword)': 'esa_maap', 'number_queries': '4'},
#  {'tolower(keyword)': 'atl', 'number_queries': '4'},
#  {'tolower(keyword)': 'forest* structure* and* biomass* database',
#   'number_queries': '4'},
#  {'tolower(keyword)': 'c1201746153-nasa_maap', 'number_queries': '4'},
#  {'tolower(keyword)': 'hls', 'number_queries': '3'},
#  {'tolower(keyword)': 'jpl', 'number_queries': '3'},
#  {'tolower(keyword)': 'fsdb', 'number_queries': '3'},
#  {'tolower(keyword)': 'modis', 'number_queries': '3'},
#  {'tolower(keyword)': 'esa', 'number_queries': '3'},
#  {'tolower(keyword)': 'uavsar', 'number_queries': '3'},
#  {'tolower(keyword)': 'gedi* ', 'number_queries': '3'},
#  {'tolower(keyword)': 'esacci', 'number_queries': '2'},
#  {'tolower(keyword)': 'water', 'number_queries': '2'},
#  {'tolower(keyword)': 'rainforest* canopy', 'number_queries': '2'},
#  {'tolower(keyword)': 'sentinel', 'number_queries': '2'},
#  {'tolower(keyword)': 'atlas/icesat-2* l3a* land* and* vegetation* height* v002',
#   'number_queries': '2'},
#  {'tolower(keyword)': 'lvis', 'number_queries': '2'},
#  {'tolower(keyword)': 'uavsar* afrisar* ', 'number_queries': '2'},
#  {'tolower(keyword)': 'uavsar_afrisar_v1_slc', 'number_queries': '2'},
#  {'tolower(keyword)': 'slc', 'number_queries': '2'},
#  {'tolower(keyword)': 'arctic-boreal* vulnerability* experiment* uninhabited* aerial* vehicle* synthetic* aperture* radar* polarimetric* sar',
#   'number_queries': '2'},
#  {'tolower(keyword)': 'icesat', 'number_queries': '2'},
#  {'tolower(keyword)': 'sar', 'number_queries': '2'},
#  {'tolower(keyword)': 'afrisar_agb_maps_1681', 'number_queries': '2'},
#  {'tolower(keyword)': 'biosar', 'number_queries': '2'},
#  {'tolower(keyword)': 'uavsar_afrisar', 'number_queries': '2'},
#  {'tolower(keyword)': 'l4b', 'number_queries': '2'},
#  {'tolower(keyword)': 'gedi_l3_landsurface_metrics_v2_1952',
#   'number_queries': '2'},
#  {'tolower(keyword)': 'llc90', 'number_queries': '1'},
#  {'tolower(keyword)': 'merr', 'number_queries': '1'},
#  {'tolower(keyword)': 'plate* tectonics', 'number_queries': '1'},
#  {'tolower(keyword)': 'tape', 'number_queries': '1'},
#  {'tolower(keyword)': 'afrisar:* rainforest* canopy* height* derived* from* polinsar* and* lidar* data,* gabon',
#   'number_queries': '1'},
#  {'tolower(keyword)': 'jpl* 2020', 'number_queries': '1'},
#  {'tolower(keyword)': 'esacci_biomass_l4_agb_v3_100m_2010',
#   'number_queries': '1'},
#  {'tolower(keyword)': 'afrisar* lvis', 'number_queries': '1'},
#  {'tolower(keyword)': 'uavsar_afrisar_v1_slc_4326_0000141205',
#   'number_queries': '1'},
#  {'tolower(keyword)': 'agb_2020', 'number_queries': '1'},
#  {'tolower(keyword)': 'gedi02_b', 'number_queries': '1'},
#  {'tolower(keyword)': 'bionmass', 'number_queries': '1'},
#  {'tolower(keyword)': 'usa_neonbarr_2019_neon_d18_barr_dp1_576000_7909000_classified_point_cloud_colorized.las.json',
#   'number_queries': '1'},
#  {'tolower(keyword)': 'neonjerc', 'number_queries': '1'},
#  {'tolower(keyword)': 'biomas', 'number_queries': '1'},
#  {'tolower(keyword)': 'uavsar* afrisar', 'number_queries': '1'},
#  {'tolower(keyword)': 'copernicus', 'number_queries': '1'},
#  {'tolower(keyword)': 'nis', 'number_queries': '1'},
#  {'tolower(keyword)': 'biom', 'number_queries': '1'},
#  {'tolower(keyword)': 'onera', 'number_queries': '1'},
#  {'tolower(keyword)': 'afrisar:* canopy* structure* derived* from* polinsar* and* coherence* tomosar* nisar* tools',
#   'number_queries': '1'},
#  {'tolower(keyword)': '2020', 'number_queries': '1'},
#  {'tolower(keyword)': 'circulation', 'number_queries': '1'},
#  {'tolower(keyword)': 'ablvis', 'number_queries': '1'},
#  {'tolower(keyword)': 'gedi* l4a* ', 'number_queries': '1'},
#  {'tolower(keyword)': 'gedi* calval', 'number_queries': '1'},
#  {'tolower(keyword)': 'dbh* tape1', 'number_queries': '1'},
#  {'tolower(keyword)': 'gedi* l2a', 'number_queries': '1'},
#  {'tolower(keyword)': 'trop', 'number_queries': '1'},
#  {'tolower(keyword)': 'calval', 'number_queries': '1'},
#  {'tolower(keyword)': 'uavsar_afrisar_v1', 'number_queries': '1'},
#  {'tolower(keyword)': 'uavsar* afrisar* v1* slc', 'number_queries': '1'},
#  {'tolower(keyword)': 'agb* 2020', 'number_queries': '1'},
#  {'tolower(keyword)': 'population', 'number_queries': '1'},
#  {'tolower(keyword)': 'viirs/npp* raw* radiances* in* counts* 6-min* l1a* swath* nrt',
#   'number_queries': '1'},
#  {'tolower(keyword)': 'dbh', 'number_queries': '1'},
#  {'tolower(keyword)': 'srtm', 'number_queries': '1'},
#  {'tolower(keyword)': 'esacci_biomass_l4_agb_v3_100m_2017',
#   'number_queries': '1'},
#  {'tolower(keyword)': 'tropisar', 'number_queries': '1'},
#  {'tolower(keyword)': 'c1200231010-nasa_maap', 'number_queries': '1'},
#  {'tolower(keyword)': 'maap', 'number_queries': '1'},
#  {'tolower(keyword)': 'boreal* agb', 'number_queries': '1'},
#  {'tolower(keyword)': 'indrex', 'number_queries': '1'},
#  {'tolower(keyword)': 'cal/val', 'number_queries': '1'},
#  {'tolower(keyword)': 'surface* elevation', 'number_queries': '1'},
#  {'tolower(keyword)': 'ecco', 'number_queries': '1'},
#  {'tolower(keyword)': 'ocean', 'number_queries': '1'},
#  {'tolower(keyword)': 'llc', 'number_queries': '1'},
#  {'tolower(keyword)': 'merra-2', 'number_queries': '1'},
#  {'tolower(keyword)': 'afrisar_lvis_biomass_vprofiles_1775',
#   'number_queries': '1'},
#  {'tolower(keyword)': 'afrisar:* gridded* forest* biomass* and* canopy* metrics* derived* from* lvis,* gabon,* 2016',
#   'number_queries': '1'},
#  {'tolower(keyword)': 'brix', 'number_queries': '1'},
#  {'tolower(keyword)': 'edav', 'number_queries': '1'}]

# %%
count_data = {}

for result in restructured_data:
    if 'tolower(keyword)' in result:
        count_data[result['tolower(keyword)']] = int(result['number_queries'])

count_data = {k: v for k, v in sorted(count_data.items(), key=lambda item: item[1], reverse=True)}
count_data
# Out:
# {'gedi': 81,
#  'biomass': 40,
#  'gedi* l2b': 40,
#  'afrisar': 22,
#  'afrisar_dlr': 21,
#  'gedi* l4b': 18,
#  'atl08': 18,
#  'gedi* l4a': 10,
#  'cci': 10,
#  'afrisar_uavsar_coreg_slc': 9,
#  'l2b': 9,
#  'afrisar* uavsar* coregistered* slcs* generated* using* nisar* tools': 8,
#  'afrisar:* aboveground* biomass* for* lope,* mabounie,* mondah,* and* rabi* sites,* gabon': 7,
#  'aflvis2': 7,
#  'atl03': 6,
#  'viirs': 6,
#  'biosar1': 6,
#  'dem': 6,
#  'l4a': 6,
#  'landsat': 5,
#  'neon': 5,
#  'dbh* tape': 4,
#  'gedi* l3': 4,
#  'l2a': 4,
#  'esa_maap': 4,
#  'atl': 4,
#  'forest* structure* and* biomass* database': 4,
#  'c1201746153-nasa_maap': 4,
#  'hls': 3,
#  'jpl': 3,
#  'fsdb': 3,
#  'modis': 3,
#  'esa': 3,
#  'uavsar': 3,
#  'gedi* ': 3,
#  'esacci': 2,
#  'water': 2,
#  'rainforest* canopy': 2,
#  'sentinel': 2,
#  'atlas/icesat-2* l3a* land* and* vegetation* height* v002': 2,
#  'lvis': 2,
#  'uavsar* afrisar* ': 2,
#  'uavsar_afrisar_v1_slc': 2,
#  'slc': 2,
#  'arctic-boreal* vulnerability* experiment* uninhabited* aerial* vehicle* synthetic* aperture* radar* polarimetric* sar': 2,
#  'icesat': 2,
#  'sar': 2,
#  'afrisar_agb_maps_1681': 2,
#  'biosar': 2,
#  'uavsar_afrisar': 2,
#  'l4b': 2,
#  'gedi_l3_landsurface_metrics_v2_1952': 2,
#  'llc90': 1,
#  'merr': 1,
#  'plate* tectonics': 1,
#  'tape': 1,
#  'afrisar:* rainforest* canopy* height* derived* from* polinsar* and* lidar* data,* gabon': 1,
#  'jpl* 2020': 1,
#  'esacci_biomass_l4_agb_v3_100m_2010': 1,
#  'afrisar* lvis': 1,
#  'uavsar_afrisar_v1_slc_4326_0000141205': 1,
#  'agb_2020': 1,
#  'gedi02_b': 1,
#  'bionmass': 1,
#  'usa_neonbarr_2019_neon_d18_barr_dp1_576000_7909000_classified_point_cloud_colorized.las.json': 1,
#  'neonjerc': 1,
#  'biomas': 1,
#  'uavsar* afrisar': 1,
#  'copernicus': 1,
#  'nis': 1,
#  'biom': 1,
#  'onera': 1,
#  'afrisar:* canopy* structure* derived* from* polinsar* and* coherence* tomosar* nisar* tools': 1,
#  '2020': 1,
#  'circulation': 1,
#  'ablvis': 1,
#  'gedi* l4a* ': 1,
#  'gedi* calval': 1,
#  'dbh* tape1': 1,
#  'gedi* l2a': 1,
#  'trop': 1,
#  'calval': 1,
#  'uavsar_afrisar_v1': 1,
#  'uavsar* afrisar* v1* slc': 1,
#  'agb* 2020': 1,
#  'population': 1,
#  'viirs/npp* raw* radiances* in* counts* 6-min* l1a* swath* nrt': 1,
#  'dbh': 1,
#  'srtm': 1,
#  'esacci_biomass_l4_agb_v3_100m_2017': 1,
#  'tropisar': 1,
#  'c1200231010-nasa_maap': 1,
#  'maap': 1,
#  'boreal* agb': 1,
#  'indrex': 1,
#  'cal/val': 1,
#  'surface* elevation': 1,
#  'ecco': 1,
#  'ocean': 1,
#  'llc': 1,
#  'merra-2': 1,
#  'afrisar_lvis_biomass_vprofiles_1775': 1,
#  'afrisar:* gridded* forest* biomass* and* canopy* metrics* derived* from* lvis,* gabon,* 2016': 1,
#  'brix': 1,
#  'edav': 1}

# %%
# data set
limit = 10
keywords = list(count_data.keys())[0:limit]
number_queries = list(count_data.values())[0:limit]

plt.figure(figsize=(9, 4), dpi=96)

def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center', va= 'bottom')

plt.bar(keywords, number_queries, color='y')
addlabels(keywords, number_queries)
plt.xticks(rotation=30, ha='right')
plt.show()
