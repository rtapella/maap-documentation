# %%
import boto3
from datetime import datetime, timedelta
import json
import matplotlib.pyplot as plt
import requests
import time

# %%
# NOTE: You will need to set AWS access keys for the MCP environment

# %%
# %%time
client = boto3.client('logs', region_name='us-west-2')

concept_type = "granules"
query = """
fields @timestamp, @message
| filter @message like "cmr.search.api"
| filter @message like "Searching for """ + concept_type + '"' + """
| filter @message like "short_name"
| parse @message /:short_name "(?<short_name>(\w|-)+)"/
| stats count(*) as number_queries by short_name
| sort by number_queries desc
"""

print(query)
log_group = 'cmr-search-ops'
datetime_str = '05/18/22 00:00:00'
starting_datetime_object = datetime.strptime(datetime_str, '%m/%d/%y %H:%M:%S')

start_query_response = client.start_query(
    logGroupName=log_group,
    startTime=int(starting_datetime_object.timestamp()),
    endTime=int(datetime.now().timestamp()),
    queryString=query,
)

query_id = start_query_response['queryId']

logs_response = None

while logs_response == None or logs_response['status'] == 'Running':
    print('Waiting for query to complete ...')
    time.sleep(10)
    logs_response = client.get_query_results(
        queryId=query_id
    )
# Out:
# fields @timestamp, @message
# | filter @message like "cmr.search.api"
# | filter @message like "Searching for granules"
# | filter @message like "short_name"
# | parse @message /:short_name "(?<short_name>(\w|-)+)"/
# | stats count(*) as number_queries by short_name
# | sort by number_queries desc
#
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# Waiting for query to complete ...
# CPU times: user 986 ms, sys: 108 ms, total: 1.09 s
# Wall time: 9min 54s

# %%
# Save the results so we don't have to re-run the query
filename = f"{concept_type}_short_name_search-{query_id}.json"
with open(filename, "w+") as f:
    f.write(json.dumps(logs_response))
    f.close()

# %%
data = json.loads(open(filename).read())
data
# Out:
# {'results': [[{'field': 'short_name', 'value': 'AFRISAR_DLR'},
#    {'field': 'number_queries', 'value': '4743'}],
#   [{'field': 'short_name', 'value': 'GEDI02_A'},
#    {'field': 'number_queries', 'value': '2255'}],
#   [{'field': 'short_name', 'value': 'INDREX2'},
#    {'field': 'number_queries', 'value': '1446'}],
#   [{'field': 'short_name', 'value': 'AFRISAR_ONERA'},
#    {'field': 'number_queries', 'value': '984'}],
#   [{'field': 'short_name', 'value': 'TROPISAR'},
#    {'field': 'number_queries', 'value': '590'}],
#   [{'field': 'short_name', 'value': 'BIOSAR1'},
#    {'field': 'number_queries', 'value': '460'}],
#   [{'field': 'short_name', 'value': 'GEDI02_B'},
#    {'field': 'number_queries', 'value': '451'}],
#   [{'field': 'short_name', 'value': 'ATL08'},
#    {'field': 'number_queries', 'value': '384'}],
#   [{'field': 'short_name', 'value': 'AfriSAR_UAVSAR_Coreg_SLC'},
#    {'field': 'number_queries', 'value': '262'}],
#   [{'field': 'short_name', 'value': 'BIOSAR2'},
#    {'field': 'number_queries', 'value': '196'}],
#   [{'field': 'short_name', 'value': 'ATL03'},
#    {'field': 'number_queries', 'value': '190'}],
#   [{'field': 'short_name', 'value': 'ATL08_ARD-beta'},
#    {'field': 'number_queries', 'value': '143'}],
#   [{'field': 'short_name', 'value': 'AFLVIS2'},
#    {'field': 'number_queries', 'value': '127'}],
#   [{'field': 'short_name', 'value': 'BIOSAR3'},
#    {'field': 'number_queries', 'value': '110'}],
#   [{'field': 'short_name', 'value': 'SRTMGL1_COD'},
#    {'field': 'number_queries', 'value': '86'}],
#   [{'field': 'short_name', 'value': 'ABoVE_UAVSAR_PALSAR'},
#    {'field': 'number_queries', 'value': '57'}],
#   [{'field': 'short_name', 'value': 'ABLVIS1B'},
#    {'field': 'number_queries', 'value': '56'}],
#   [{'field': 'short_name', 'value': 'GEDI_L4B_Gridded_Biomass_2017'},
#    {'field': 'number_queries', 'value': '47'}],
#   [{'field': 'short_name', 'value': 'Afrisar_LVIS_Biomass_VProfiles_1775'},
#    {'field': 'number_queries', 'value': '43'}],
#   [{'field': 'short_name', 'value': 'ABLVIS2'},
#    {'field': 'number_queries', 'value': '21'}],
#   [{'field': 'short_name', 'value': 'PolInSAR_Canopy_Height_1589'},
#    {'field': 'number_queries', 'value': '20'}],
#   [{'field': 'short_name', 'value': 'Polarimetric_CT_1601'},
#    {'field': 'number_queries', 'value': '18'}],
#   [{'field': 'short_name', 'value': 'GEDI_L3_LandSurface_Metrics_V2_1952'},
#    {'field': 'number_queries', 'value': '14'}],
#   [{'field': 'short_name', 'value': 'ESACCI_Biomass_L4_AGB_V3_100m_2017'},
#    {'field': 'number_queries', 'value': '12'}],
#   [{'field': 'short_name', 'value': 'ESACCI_Biomass_L4_AGB_V3_100m_2010'},
#    {'field': 'number_queries', 'value': '12'}],
#   [{'field': 'short_name', 'value': 'Global_Forest_Change_2000-2017'},
#    {'field': 'number_queries', 'value': '12'}],
#   [{'field': 'short_name', 'value': 'GEDI_L3_LandSurface_Metrics'},
#    {'field': 'number_queries', 'value': '9'}],
#   [{'field': 'short_name', 'value': 'nceo_africa_2017'},
#    {'field': 'number_queries', 'value': '9'}],
#   [{'field': 'short_name', 'value': 'ESACCI_Biomass_L4_AGB_V3_100m_2018'},
#    {'field': 'number_queries', 'value': '8'}],
#   [{'field': 'short_name', 'value': 'L2_USER_DATA'},
#    {'field': 'number_queries', 'value': '7'}],
#   [{'field': 'short_name', 'value': 'AfriSAR_Mondah_Field_Data_1580'},
#    {'field': 'number_queries', 'value': '7'}],
#   [{'field': 'short_name', 'value': 'HLSL30'},
#    {'field': 'number_queries', 'value': '7'}],
#   [{'field': 'short_name', 'value': 'AfriSAR_AGB_Maps_1681'},
#    {'field': 'number_queries', 'value': '6'}],
#   [{'field': 'number_queries', 'value': '6'}],
#   [{'field': 'short_name', 'value': 'GEDI_L4A_AGB_Density_V2_1_2056'},
#    {'field': 'number_queries', 'value': '6'}],
#   [{'field': 'short_name', 'value': 'AfriSAR_UAVSAR_Geocoded_SLC'},
#    {'field': 'number_queries', 'value': '5'}],
#   [{'field': 'short_name', 'value': 'SENTINEL-1A_DP_GRD_HIGH'},
#    {'field': 'number_queries', 'value': '5'}],
#   [{'field': 'short_name', 'value': 'AfriSAR_UAVSAR_SLC'},
#    {'field': 'number_queries', 'value': '4'}],
#   [{'field': 'short_name', 'value': 'GEDI01_B'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'short_name', 'value': 'GEDI_CalVal_Lidar_Data'},
#    {'field': 'number_queries', 'value': '2'}],
#   [{'field': 'short_name', 'value': 'AfriSAR_UAVSAR_Geocoded_Covariance'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'short_name', 'value': 'GEDI_L4A_AGB_Density_V2_1986'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'short_name', 'value': 'ALFVIS2'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'short_name', 'value': 'l2a'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'short_name', 'value': 'uavsar_AfriSAR_v1_SLC_4326_0000141205'},
#    {'field': 'number_queries', 'value': '1'}],
#   [{'field': 'short_name', 'value': 'L2A'},
#    {'field': 'number_queries', 'value': '1'}]],
#  'statistics': {'recordsMatched': 12828.0,
#   'recordsScanned': 13099604.0,
#   'bytesScanned': 3411387557.0},
#  'status': 'Complete',
#  'ResponseMetadata': {'RequestId': 'a932a7ca-ce6a-483e-90c1-2b3c8e6ee1cc',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'a932a7ca-ce6a-483e-90c1-2b3c8e6ee1cc',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '4396',
#    'date': 'Wed, 19 Oct 2022 21:07:35 GMT'},
#   'RetryAttempts': 0}}

# %%
restructured_data = []
for result in logs_response['results']:
    entry_data = {}
    for entry in result:
        entry_data[entry['field']] = entry['value']
    restructured_data.append(entry_data)

restructured_data
# Out:
# [{'short_name': 'AFRISAR_DLR', 'number_queries': '4743'},
#  {'short_name': 'GEDI02_A', 'number_queries': '2255'},
#  {'short_name': 'INDREX2', 'number_queries': '1446'},
#  {'short_name': 'AFRISAR_ONERA', 'number_queries': '984'},
#  {'short_name': 'TROPISAR', 'number_queries': '590'},
#  {'short_name': 'BIOSAR1', 'number_queries': '460'},
#  {'short_name': 'GEDI02_B', 'number_queries': '451'},
#  {'short_name': 'ATL08', 'number_queries': '384'},
#  {'short_name': 'AfriSAR_UAVSAR_Coreg_SLC', 'number_queries': '262'},
#  {'short_name': 'BIOSAR2', 'number_queries': '196'},
#  {'short_name': 'ATL03', 'number_queries': '190'},
#  {'short_name': 'ATL08_ARD-beta', 'number_queries': '143'},
#  {'short_name': 'AFLVIS2', 'number_queries': '127'},
#  {'short_name': 'BIOSAR3', 'number_queries': '110'},
#  {'short_name': 'SRTMGL1_COD', 'number_queries': '86'},
#  {'short_name': 'ABoVE_UAVSAR_PALSAR', 'number_queries': '57'},
#  {'short_name': 'ABLVIS1B', 'number_queries': '56'},
#  {'short_name': 'GEDI_L4B_Gridded_Biomass_2017', 'number_queries': '47'},
#  {'short_name': 'Afrisar_LVIS_Biomass_VProfiles_1775', 'number_queries': '43'},
#  {'short_name': 'ABLVIS2', 'number_queries': '21'},
#  {'short_name': 'PolInSAR_Canopy_Height_1589', 'number_queries': '20'},
#  {'short_name': 'Polarimetric_CT_1601', 'number_queries': '18'},
#  {'short_name': 'GEDI_L3_LandSurface_Metrics_V2_1952', 'number_queries': '14'},
#  {'short_name': 'ESACCI_Biomass_L4_AGB_V3_100m_2017', 'number_queries': '12'},
#  {'short_name': 'ESACCI_Biomass_L4_AGB_V3_100m_2010', 'number_queries': '12'},
#  {'short_name': 'Global_Forest_Change_2000-2017', 'number_queries': '12'},
#  {'short_name': 'GEDI_L3_LandSurface_Metrics', 'number_queries': '9'},
#  {'short_name': 'nceo_africa_2017', 'number_queries': '9'},
#  {'short_name': 'ESACCI_Biomass_L4_AGB_V3_100m_2018', 'number_queries': '8'},
#  {'short_name': 'L2_USER_DATA', 'number_queries': '7'},
#  {'short_name': 'AfriSAR_Mondah_Field_Data_1580', 'number_queries': '7'},
#  {'short_name': 'HLSL30', 'number_queries': '7'},
#  {'short_name': 'AfriSAR_AGB_Maps_1681', 'number_queries': '6'},
#  {'number_queries': '6'},
#  {'short_name': 'GEDI_L4A_AGB_Density_V2_1_2056', 'number_queries': '6'},
#  {'short_name': 'AfriSAR_UAVSAR_Geocoded_SLC', 'number_queries': '5'},
#  {'short_name': 'SENTINEL-1A_DP_GRD_HIGH', 'number_queries': '5'},
#  {'short_name': 'AfriSAR_UAVSAR_SLC', 'number_queries': '4'},
#  {'short_name': 'GEDI01_B', 'number_queries': '2'},
#  {'short_name': 'GEDI_CalVal_Lidar_Data', 'number_queries': '2'},
#  {'short_name': 'AfriSAR_UAVSAR_Geocoded_Covariance', 'number_queries': '1'},
#  {'short_name': 'GEDI_L4A_AGB_Density_V2_1986', 'number_queries': '1'},
#  {'short_name': 'ALFVIS2', 'number_queries': '1'},
#  {'short_name': 'l2a', 'number_queries': '1'},
#  {'short_name': 'uavsar_AfriSAR_v1_SLC_4326_0000141205',
#   'number_queries': '1'},
#  {'short_name': 'L2A', 'number_queries': '1'}]

# %%
count_data = {}
for result in restructured_data:
    if 'short_name' in result:
        count_data[result['short_name']] = int(result['number_queries'])

count_data = {k: v for k, v in sorted(count_data.items(), key=lambda item: item[1], reverse=True)}

# %%
# data set
limit = 20
short_names = list(count_data.keys())[0:limit]
number_queries = list(count_data.values())[0:limit]

plt.figure(figsize=(9, 4), dpi=96)

def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center', va= 'bottom')

plt.bar(short_names, number_queries, color='y')
addlabels(short_names, number_queries)
plt.xticks(rotation=30, ha='right')
plt.show()
